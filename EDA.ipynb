# %%
pip install --upgrade tensorflow import os
# Out:
# ...
#   Using cached tensorflow-2.13.0-cp39-cp39-win_amd64.whl (1.9 kB)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -eras (c:\users\lakshmi\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\lakshmi\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\lakshmi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -eras (c:\users\lakshmi\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\lakshmi\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\lakshmi\anaconda3\lib\site-packages)
# ERROR: Could not find a version that satisfies the requirement import (from versions: none)
# ERROR: No matching distribution found for import
# ...

# %%
pip install tqdm
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -eras (c:\users\lakshmi\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\lakshmi\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\lakshmi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -eras (c:\users\lakshmi\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\lakshmi\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\lakshmi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -eras (c:\users\lakshmi\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\lakshmi\appdata\roaming\python\python39\site-packages)
# ...

# %%
pip install librosa soundfile
# Out:
# ...
# WARNING: Ignoring invalid distribution -eras (c:\users\lakshmi\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\lakshmi\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\lakshmi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -eras (c:\users\lakshmi\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\lakshmi\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\lakshmi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -eras (c:\users\lakshmi\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\lakshmi\appdata\roaming\python\python39\site-packages)
# ...

# %% [markdown]
# ### Loading the Dataset

# %%
 main_dir = 'C:/Users/Lakshmi/Desktop/Main project/audio_dataset'

# %%
audio_data = []
file_names = []

# %%
# loading the audio data
for root, dirs, files in os.walk(main_dir):
    for file in files:
        if file.endswith('.ogg'):
            print("Loading:", file)
            file_path = os.path.join(root, file)
            y, sr = librosa.load(file_path, sr=None)
            audio_data.append(y)
            file_names.append(file)
# Out:
# Loading: WhatsApp Audio 2023-08-30 at 9.14.49 PM (1).ogg
# Loading: WhatsApp Audio 2023-08-30 at 9.14.49 PM.ogg
# Loading: WhatsApp Audio 2023-08-30 at 9.16.01 PM (1).ogg
# Loading: WhatsApp Audio 2023-08-30 at 9.16.01 PM.ogg
# Loading: WhatsApp Audio 2023-08-30 at 9.17.02 PM (1).ogg
# Loading: WhatsApp Audio 2023-08-30 at 9.17.02 PM (2).ogg
# Loading: WhatsApp Audio 2023-08-30 at 9.17.02 PM (3).ogg
# Loading: WhatsApp Audio 2023-08-30 at 9.17.02 PM (4).ogg
# Loading: WhatsApp Audio 2023-08-30 at 9.17.02 PM.ogg
# Loading: WhatsApp Audio 2023-08-30 at 9.20.09 PM (1).ogg
# Loading: WhatsApp Audio 2023-08-30 at 9.20.09 PM.ogg
# Loading: WhatsApp Audio 2023-08-30 at 9.20.10 PM (1).ogg
# Loading: WhatsApp Audio 2023-08-30 at 9.20.10 PM (2).ogg
# Loading: WhatsApp Audio 2023-08-30 at 9.20.10 PM (3).ogg
# Loading: WhatsApp Audio 2023-08-30 at 9.20.10 PM (4).ogg
# Loading: WhatsApp Audio 2023-08-30 at 9.20.10 PM.ogg
# Loading: WhatsApp Audio 2023-08-30 at 9.21.39 PM.ogg
# ...

# %%
filename_1 = r'audio_dataset/train/day_1/WhatsApp Audio 2023-09-01 at 12.13.34 AM (2).ogg'

plt.figure(figsize=(14, 5))
data, sample_rate = librosa.load(filename_1)
plt.plot(data)
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('MONDAY')
plt.show()

ipd.Audio(filename_1)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/ogg;base64,..." type="audio/ogg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
filename_2 = r'audio_dataset/train/day_2/WhatsApp Audio 2023-07-06 at 7.35.35 PM.ogg'
plt.figure(figsize=(14, 5))
data, sample_rate = librosa.load(filename_2)
plt.plot(data)
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('TUESDAY')
plt.show()

ipd.Audio(filename_2)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/ogg;base64,..." type="audio/ogg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
filename_3 = r'audio_dataset/train/day_3/WhatsApp Audio 2023-07-06 at 7.45.04 PM.ogg'
plt.figure(figsize=(14, 5))
data, sample_rate = librosa.load(filename_3)
plt.plot(data)
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('WEDNESDAY')
plt.show()

ipd.Audio(filename_3)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/ogg;base64,..." type="audio/ogg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
filename_4 = r'audio_dataset/train/day_4/WhatsApp Audio 2023-07-06 at 7.51.31 PM.ogg'
plt.figure(figsize=(14, 5))
data, sample_rate = librosa.load(filename_4)
plt.plot(data)
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('THURSDAY')
plt.show()

ipd.Audio(filename_4)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/ogg;base64,..." type="audio/ogg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
filename_5 = r'audio_dataset/train/day_5/WhatsApp Audio 2023-07-07 at 3.43.39 PM (1).ogg'
plt.figure(figsize=(14, 5))
data, sample_rate = librosa.load(filename_5)
plt.plot(data)
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('FRIDAY')
plt.show()

ipd.Audio(filename_5)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/ogg;base64,..." type="audio/ogg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
filename_6 = r'audio_dataset/train/day_6/WhatsApp Audio 2023-07-12 at 4.12.09 PM (2).ogg'

plt.figure(figsize=(14, 5))
data, sample_rate = librosa.load(filename_6)
plt.plot(data)
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('SATURDAY')
plt.show()

ipd.Audio(filename_6)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/ogg;base64,..." type="audio/ogg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
filename_7 = r'audio_dataset/train/day_7/WhatsApp Audio 2023-09-01 at 6.42.00 PM (1).ogg'
plt.figure(figsize=(14, 5))
data, sample_rate = librosa.load(filename_7)
plt.plot(data)
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('SUNDAY')
plt.show()

ipd.Audio(filename_7)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/ogg;base64,..." type="audio/ogg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### Visualisations on dataset

# %%
import librosa.display
import matplotlib.pyplot as plt

sample_index = 0

# Ploting the audio waveform

plt.figure(figsize=(12, 6))
plt.subplot(2, 1, 1)
librosa.display.waveshow(audio_data[sample_index], sr=sr)
plt.title('Audio Waveform')
plt.xlabel('Time')
plt.ylabel('Amplitude')
# Out:
# Text(72.75, 0.5, 'Amplitude')

# %%
import librosa.display
import matplotlib.pyplot as plt

sample_index = 0

# Compute the mel spectrogram
mel_spectrogram = librosa.feature.melspectrogram(y=audio_data[sample_index], sr=sr)

# Ploting the mel spectrogram
plt.figure(figsize=(10, 4))
librosa.display.specshow(librosa.power_to_db(mel_spectrogram, ref=np.max), sr=sr, x_axis='time', y_axis='mel')
plt.colorbar(format='%+2.0f dB')
plt.title('Mel Spectrogram')
plt.xlabel('Time')
plt.ylabel('Mel Frequency')
plt.tight_layout()

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

sample_index = 0

# Calculating the amplitude envelope
amplitude_envelope = np.abs(audio_data[sample_index])

# Ploting the amplitude envelope
plt.figure(figsize=(10, 4))
plt.plot(np.arange(len(amplitude_envelope)) / sr, amplitude_envelope)
plt.title('Amplitude Envelope')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.tight_layout()

plt.show()

# %%
import librosa.display
import matplotlib.pyplot as plt

sample_index = 0

# Calculating MFCCs
mfccs = librosa.feature.mfcc(y=audio_data[sample_index], sr=sr, n_mfcc=13)

# Plot MFCCs
plt.figure(figsize=(10, 4))
librosa.display.specshow(mfccs, x_axis='time')
plt.colorbar()
plt.title('MFCCs')
plt.tight_layout()

plt.show()

# %%
sample_index = 1

# Calculating the spectrogram
D = librosa.amplitude_to_db(np.abs(librosa.stft(audio_data[sample_index])), ref=np.max)

# Plot the spectrogram
plt.figure(figsize=(10, 4))
librosa.display.specshow(D, sr=sr, x_axis='time', y_axis='log')
plt.colorbar(format='%+2.0f dB')
plt.title('Spectrogram')
plt.tight_layout()

plt.show()

# %%
#visualizing a audio file in Harmonics and Perceptrual
audio_file = r'audio_dataset/train/day_3/WhatsApp Audio 2023-07-06 at 7.45.04 PM.ogg'
y, sr = librosa.load(audio_file)

# Calculate harmonic-percussive source separation
harmonic, percussive = librosa.effects.hpss(y)

# Plot harmonic component
plt.figure(figsize=(8, 4))
librosa.display.waveshow(harmonic, sr=sr)
plt.title('Harmonic Component')
plt.tight_layout()

# Plot percussive component
plt.figure(figsize=(8, 4))
librosa.display.waveshow(percussive, sr=sr)
plt.title('Percussive Component')
plt.tight_layout()

plt.show()

# %%
#visualising the spectrogram of just one audio

audio_path = 'audio_dataset/train/day_2/WhatsApp Audio 2023-09-01 at 12.26.16 AM (2).ogg'

y, sr = librosa.load(audio_path)

D = np.abs(librosa.stft(y))

# Ploting the spectrogram
plt.figure(figsize=(10, 4))
librosa.display.specshow(D, sr=sr, x_axis='time', y_axis='log')
plt.colorbar(format='%+2.0f dB')
plt.title('Spectrogram')
plt.tight_layout()

plt.show()
ipd.Audio(audio_path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/ogg;base64,..." type="audio/ogg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### Statistical Analysis

# %%
import numpy as np
from scipy import stats

# Calculating mean, median, and standard deviation of audio durations
durations = [len(audio) for audio in audio_data]
mean_duration = np.mean(durations)
median_duration = np.median(durations)
std_duration = np.std(durations)

# Calculating skewness and kurtosis of audio durations
skewness = stats.skew(durations)
kurtosis = stats.kurtosis(durations)

# Performing a Shapiro-Wilk test 
shapiro_test_statistic, shapiro_p_value = stats.shapiro(durations)

# Print the results
print(f"Mean Duration: {mean_duration:.2f}")
print(f"Median Duration: {median_duration}")
print(f"Standard Deviation of Duration: {std_duration:.2f}")
print(f"Skewness of Duration: {skewness:.2f}")
print(f"Kurtosis of Duration: {kurtosis:.2f}")
print(f"Shapiro-Wilk Test Statistic: {shapiro_test_statistic:.2f}")
# Out:
# Mean Duration: 21739.22
# Median Duration: 19736.0
# Standard Deviation of Duration: 6893.28
# Skewness of Duration: 1.47
# Kurtosis of Duration: 1.99
# Shapiro-Wilk Test Statistic: 0.81

# %%
from scipy.stats import skew, kurtosis


dataset_root = 'C:/Users/Lakshmi/Desktop/Main project/audio_dataset'


subdirs = ['train', 'test']

# List of categories 
categories = ['day_1', 'day_2', 'day_3', 'day_4', 'day_5', 'day_6', 'day_7']


moments_train = {}
moments_test = {}

# Iterate through subdirectories
for subdir in subdirs:
    subdir_path = os.path.join(dataset_root, subdir)
    

    moments_subdir = {}
    
    # Iterate through categories
    for category in categories:
        category_path = os.path.join(subdir_path, category)
        durations = []

        # Iterate through audio files in the current category
        for filename in os.listdir(category_path):
            if filename.endswith('.ogg'):
                file_path = os.path.join(category_path, filename)
               # print("Loading:", file_path)  
                audio_data, sr = librosa.load(file_path, sr=None)
                duration = librosa.get_duration(y=audio_data, sr=sr)
                durations.append(duration)

        # Calculate moments 
        moments = {
            'mean': np.mean(durations), 
            'variance': np.var(durations), 
            'skewness': skew(durations),
            'kurtosis': kurtosis(durations)
        }

        # Store moments in the dictionary 
        moments_subdir[category] = moments
    
    # Store moments for the current subdirectory
    if subdir == 'train':
        moments_train = moments_subdir
    elif subdir == 'test':
        moments_test = moments_subdir

# Print the calculated moments for train and test parts
print("Train Part Moments:", moments_train) 
print("\n")
print("Test Part Moments:", moments_test)
# Out:
# Train Part Moments: {'day_1': {'mean': 1.4525768072289154, 'variance': 0.17357312201857128, 'skewness': 0.8344507500835358, 'kurtosis': 0.09178443507571332}, 'day_2': {'mean': 1.3040193014705879, 'variance': 0.1419005819459275, 'skewness': 1.6911639520589767, 'kurtosis': 3.5836994841793786}, 'day_3': {'mean': 1.1071354166666667, 'variance': 0.03931603895399305, 'skewness': 2.080046058819878, 'kurtosis': 3.905014123183519}, 'day_4': {'mean': 1.4087252604166665, 'variance': 0.22948428332349993, 'skewness': 1.177610822767011, 'kurtosis': 0.5954813937395103}, 'day_5': {'mean': 1.4030520833333333, 'variance': 0.169397588931015, 'skewness': 1.3906614104637436, 'kurtosis': 1.9693252176254195}, 'day_6': {'mean': 1.396292361111111, 'variance': 0.17833642186005016, 'skewness': 1.251842827336018, 'kurtosis': 1.4573190156453286}, 'day_7': {'mean': 1.2276063988095238, 'variance': 0.16739253718189756, 'skewness': 2.1446092947931215, 'kurtosis': 4.274450017006749}}
#
#
# ...

# %%
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt


mean_values = [moments_train[category]['mean'] for category in categories]
variance_values = [moments_train[category]['variance'] for category in categories]
skewness_values = [moments_train[category]['skewness'] for category in categories]
kurtosis_values = [moments_train[category]['kurtosis'] for category in categories]


plt.figure(figsize=(12, 6))

# Mean
plt.subplot(2, 2, 1)
plt.bar(categories, mean_values)
plt.title('Mean')
plt.xlabel('Categories')
plt.xticks(rotation=45)

# Variance
plt.subplot(2, 2, 2)
plt.bar(categories, variance_values)
plt.title('Variance')
plt.xlabel('Categories')
plt.xticks(rotation=45)

# Skewness
plt.subplot(2, 2, 3)
plt.bar(categories, skewness_values)
plt.title('Skewness')
plt.xlabel('Categories')
plt.xticks(rotation=45)

# Kurtosis
plt.subplot(2, 2, 4)
plt.bar(categories, kurtosis_values)
plt.title('Kurtosis')
plt.xlabel('Categories')
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()
